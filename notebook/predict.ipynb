# %%
import pandas as pd
import joblib

# %%
def load_model(model_path):
    """Load and return the model from the specified path."""
    return joblib.load(model_path)

# %%
def get_user_input():
    """Get user input for prediction features."""
    print("Enter the features for prediction:")
    features = {
        'CRIM': float(input("CRIM: ")),
        'ZN': float(input("ZN: ")),
        'INDUS': float(input("INDUS: ")),
        'CHAS': float(input("CHAS: ")),
        'NOX': float(input("NOX: ")),
        'RM': float(input("RM: ")),
        'AGE': float(input("AGE: ")),
        'DIS': float(input("DIS: ")),
        'RAD': int(input("RAD: ")),
        'TAX': int(input("TAX: ")),
        'PTRATIO': float(input("PTRATIO: ")),
        'B': float(input("B: ")),
        'LSTAT': float(input("LSTAT: "))
    }
    return pd.DataFrame([features])

# %%
def make_prediction(model, input_df):
    """Make a prediction using the provided model and input DataFrame."""
    prediction = model.predict(input_df)
    return prediction[0]

# %%
if __name__ == "__main__":
    model_path = model_path = '/Volumes/Code/BostonHousingModel/models/linear_regression_model.pkl'
    model = load_model(model_path)

    # Get user input and make prediction
    input_df = get_user_input()
    predicted_value = make_prediction(model, input_df)
    print(f"Predicted MEDV: ${predicted_value:.2f}")
# Out:
# Enter the features for prediction:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       3 model = load_model(model_path)
#       5 # Get user input and make prediction
# ----> 6 input_df = get_user_input()
#       7 predicted_value = make_prediction(model, input_df)
#       8 print(f"Predicted MEDV: ${predicted_value:.2f}")
#
# Cell In[4], line 5, in get_user_input()
#       2 """Get user input for prediction features."""
#       3 print("Enter the features for prediction:")
#       4 features = {
# ----> 5     'CRIM': float(input("CRIM: ")),
#       6     'ZN': float(input("ZN: ")),
#       7     'INDUS': float(input("INDUS: ")),
#       8     'CHAS': float(input("CHAS: ")),
#       9     'NOX': float(input("NOX: ")),
#      10     'RM': float(input("RM: ")),
#      11     'AGE': float(input("AGE: ")),
#      12     'DIS': float(input("DIS: ")),
#      13     'RAD': int(input("RAD: ")),
#      14     'TAX': int(input("TAX: ")),
#      15     'PTRATIO': float(input("PTRATIO: ")),
#      16     'B': float(input("B: ")),
#      17     'LSTAT': float(input("LSTAT: "))
#      18 }
#      19 return pd.DataFrame([features])
#
# ValueError: could not convert string to float: ''
